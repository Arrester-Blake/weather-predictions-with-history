# %% [markdown]
# ## Name: Arnab Ghosh
# ## Group No: 058
# ## Group Members: Arnab Ghosh, Sarbajit Roy, RISHABH RAKESH
# ## Dataset Name: weatherHistory.csv

# %% [markdown]
# # Import Libraries & Data
# ## Predict the Humidity

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
##Preprocessing Imports

from sklearn import preprocessing

## Visualization Imports
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import seaborn as sns

##Model Building Imports
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

## Metrics Import
from sklearn.metrics import mean_squared_error,max_error,confusion_matrix

## Feature Selection Imports
from sklearn.feature_selection import SelectKBest, f_regression,mutual_info_regression

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Load Dataset
# > Use the Date Column 'Formatted Date' as the index column

# %%
weather_hourly = pd.read_csv('weatherHistory.csv',
                             index_col=['Formatted Date'],
                             na_values=['9999.99'])
weather_hourly.index = weather_hourly.index.str.replace('\+0200','')
weather_hourly.index=pd.to_datetime(weather_hourly.index,format="%Y-%m-%d %H:%M:%S", utc= True)
weather_hourly.head(5)
# Out:
#                                  Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00+00:00  Partly Cloudy        rain         9.472222
# 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         9.355556
# 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         9.377778
# 2006-04-01 03:00:00+00:00  Partly Cloudy        rain         8.288889
# 2006-04-01 04:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-04-01 00:00:00+00:00                  7.388889      0.89
# 2006-04-01 01:00:00+00:00                  7.227778      0.86
# 2006-04-01 02:00:00+00:00                  9.377778      0.89
# 2006-04-01 03:00:00+00:00                  5.944444      0.83
# 2006-04-01 04:00:00+00:00                  6.977778      0.83
#
#                            Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# 2006-04-01 00:00:00+00:00            14.1197                   251.0
# 2006-04-01 01:00:00+00:00            14.2646                   259.0
# 2006-04-01 02:00:00+00:00             3.9284                   204.0
# 2006-04-01 03:00:00+00:00            14.1036                   269.0
# 2006-04-01 04:00:00+00:00            11.0446                   259.0
#
#                            Visibility (km)  Loud Cover  Pressure (millibars)  \
# Formatted Date
# 2006-04-01 00:00:00+00:00          15.8263         0.0               1015.13
# 2006-04-01 01:00:00+00:00          15.8263         0.0               1015.63
# 2006-04-01 02:00:00+00:00          14.9569         0.0               1015.94
# 2006-04-01 03:00:00+00:00          15.8263         0.0               1016.41
# 2006-04-01 04:00:00+00:00          15.8263         0.0               1016.51
#
#                                                Daily Summary
# Formatted Date
# 2006-04-01 00:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 01:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 02:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 03:00:00+00:00  Partly cloudy throughout the day.
# 2006-04-01 04:00:00+00:00  Partly cloudy throughout the day.

# %% [markdown]
# # Data Exploration & Visualization

# %% [markdown]
# ##### Description of the dataset

# %%
weather_hourly.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %% [markdown]
# #### Shape of the dataset

# %%
weather_hourly.shape
# Out:
# (96453, 11)

# %% [markdown]
# #### Features of the Dataset

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    
print(f'{color.BOLD} Features of the dataset{color.END}')
print(f'{color.BLUE} {weather_hourly.columns} {color.END}')

print(f'{color.BOLD} Categorical features of the dataset {color.END}')
categorical_features = weather_hourly.select_dtypes(include='object').columns
print(f'{color.BLUE} {categorical_features} {color.END}')
print(f'{color.BOLD} Continous features of the dataset {color.END}')
continous_features = weather_hourly.select_dtypes(exclude='object').columns
print(f' {color.BLUE} {continous_features} {color.END}')
# Out:
#  Features of the dataset
#  Index(['Summary', 'Precip Type', 'Temperature (C)', 'Apparent Temperature (C)',
#        'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)',
#        'Visibility (km)', 'Loud Cover', 'Pressure (millibars)',
#        'Daily Summary'],
#       dtype='object')
#  Categorical features of the dataset
#  Index(['Summary', 'Precip Type', 'Daily Summary'], dtype='object')
#  Continous features of the dataset
#   Index(['Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Loud Cover', 'Pressure (millibars)'],
#       dtype='object')

# %% [markdown]
# ##### Plot Hourly Humidity

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(weather_hourly.index.values,
          weather_hourly['Humidity'],
          color='green')
ax.set(xlabel='Date',ylabel='Humidity',title='Hourly Humidity')
plt.show()

# %% [markdown]
# #### Correlation matrix for hourly data

# %%
#drop the `Loud Cover` column has it has only 0s
weather_hourly_1 = None
weather_hourly_1 = weather_hourly.drop(labels='Loud Cover',axis=1)
weather_hourly_1.corr('spearman').style.background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col0,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col1,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col0,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col1,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col2,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow3_col3,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow4_col4,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow5_col5,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow6_col6{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col2,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col6,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col0,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col1,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col3,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col5,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow6_col4{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col3{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col4{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col5{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col2{
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col3,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow4_col6,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow6_col0{
#             background-color:  #ed5f3c;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col4{
#             background-color:  #d22b27;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col5{
#             background-color:  #e6f59d;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col6{
#             background-color:  #ad0826;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col4{
#             background-color:  #c41e27;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col6{
#             background-color:  #fa9857;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow3_col0,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow4_col1{
#             background-color:  #fed683;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow3_col1,#T_990edf18_08b9_11ec_ac2f_f80dac08874crow4_col5{
#             background-color:  #fdc171;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow3_col2{
#             background-color:  #f47044;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow3_col4{
#             background-color:  #e44c34;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow3_col5{
#             background-color:  #fed27f;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow3_col6{
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow4_col0{
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow4_col2{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow4_col3{
#             background-color:  #fb9d59;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow5_col0{
#             background-color:  #cfeb85;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow5_col1{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow5_col2{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow5_col3{
#             background-color:  #fca55d;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow5_col4{
#             background-color:  #db382b;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow5_col6{
#             background-color:  #e0422f;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow6_col1{
#             background-color:  #ef633f;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow6_col2{
#             background-color:  #fede89;
#             color:  #000000;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow6_col3{
#             background-color:  #b10b26;
#             color:  #f1f1f1;
#         }#T_990edf18_08b9_11ec_ac2f_f80dac08874crow6_col5{
#             background-color:  #f57245;
#             color:  #000000;
#         }</style><table id="T_990edf18_08b9_11ec_ac2f_f80dac08874c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperature (C)</th>        <th class="col_heading level0 col1" >Apparent Temperature (C)</th>        <th class="col_heading level0 col2" >Humidity</th>        <th class="col_heading level0 col3" >Wind Speed (km/h)</th>        <th class="col_heading level0 col4" >Wind Bearing (degrees)</th>        <th class="col_heading level0 col5" >Visibility (km)</th>        <th class="col_heading level0 col6" >Pressure (millibars)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_990edf18_08b9_11ec_ac2f_f80dac08874clevel0_row0" class="row_heading level0 row0" >Temperature (C)</th>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col1" class="data row0 col1" >0.995974</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col2" class="data row0 col2" >-0.588106</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col3" class="data row0 col3" >0.016890</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col4" class="data row0 col4" >0.030243</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col5" class="data row0 col5" >0.394442</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow0_col6" class="data row0 col6" >-0.303346</td>
#             </tr>
#             <tr>
#                         <th id="T_990edf18_08b9_11ec_ac2f_f80dac08874clevel0_row1" class="row_heading level0 row1" >Apparent Temperature (C)</th>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col0" class="data row1 col0" >0.995974</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col2" class="data row1 col2" >-0.572551</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col3" class="data row1 col3" >-0.039162</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col4" class="data row1 col4" >0.027446</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col5" class="data row1 col5" >0.378676</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow1_col6" class="data row1 col6" >-0.282621</td>
#             </tr>
#             <tr>
#                         <th id="T_990edf18_08b9_11ec_ac2f_f80dac08874clevel0_row2" class="row_heading level0 row2" >Humidity</th>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col0" class="data row2 col0" >-0.588106</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col1" class="data row2 col1" >-0.572551</td>
#                         <td id="T_990edf18_08b9_11ec_ac2f_f80dac08874crow2_col2" class="data row2 c

# %% [markdown]
# * Resample Hourly Humidity to Daily Humidity
# * Plot Daily Humidity

# %%
weather_daily = weather_hourly.resample('D').aggregate('mean')
fig, ax = plt.subplots(figsize=(10,10))

ax.scatter(weather_daily.index.values,
          weather_daily['Humidity'], color='green')
ax.set(xlabel='Date',ylabel='Humidity',title='Daily Humidity')
plt.show()

# %%
weather_daily_1 = weather_daily.drop(labels='Loud Cover',axis=1)
weather_daily_1.corr('spearman').style.background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col0,#T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col1,#T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col0,#T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col1,#T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col2,#T_99487d04_08b9_11ec_84a9_f80dac08874crow3_col3,#T_99487d04_08b9_11ec_84a9_f80dac08874crow4_col4,#T_99487d04_08b9_11ec_84a9_f80dac08874crow5_col5,#T_99487d04_08b9_11ec_84a9_f80dac08874crow6_col6{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col2{
#             background-color:  #c21c27;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col3{
#             background-color:  #dc3b2c;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col4{
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col5{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col6{
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col2{
#             background-color:  #c62027;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col3{
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col4,#T_99487d04_08b9_11ec_84a9_f80dac08874crow4_col6,#T_99487d04_08b9_11ec_84a9_f80dac08874crow5_col6{
#             background-color:  #e0422f;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col5{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col6{
#             background-color:  #ad0826;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col0,#T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col1,#T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col5,#T_99487d04_08b9_11ec_84a9_f80dac08874crow3_col6,#T_99487d04_08b9_11ec_84a9_f80dac08874crow5_col2,#T_99487d04_08b9_11ec_84a9_f80dac08874crow6_col3,#T_99487d04_08b9_11ec_84a9_f80dac08874crow6_col4{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col3{
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col4{
#             background-color:  #d22b27;
#             color:  #f1f1f1;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col6{
#             background-color:  #f8864f;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow3_col0{
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow3_col1{
#             background-color:  #fa9857;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow3_col2{
#             background-color:  #fed683;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow3_col4{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow3_col5{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow4_col0{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow4_col1{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow4_col2{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow4_col3,#T_99487d04_08b9_11ec_84a9_f80dac08874crow6_col5{
#             background-color:  #fdc776;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow4_col5{
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow5_col0{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow5_col1{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow5_col3{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow5_col4{
#             background-color:  #f26841;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow6_col0{
#             background-color:  #f47044;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow6_col1{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_99487d04_08b9_11ec_84a9_f80dac08874crow6_col2{
#             background-color:  #fee999;
#             color:  #000000;
#         }</style><table id="T_99487d04_08b9_11ec_84a9_f80dac08874c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperature (C)</th>        <th class="col_heading level0 col1" >Apparent Temperature (C)</th>        <th class="col_heading level0 col2" >Humidity</th>        <th class="col_heading level0 col3" >Wind Speed (km/h)</th>        <th class="col_heading level0 col4" >Wind Bearing (degrees)</th>        <th class="col_heading level0 col5" >Visibility (km)</th>        <th class="col_heading level0 col6" >Pressure (millibars)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_99487d04_08b9_11ec_84a9_f80dac08874clevel0_row0" class="row_heading level0 row0" >Temperature (C)</th>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col1" class="data row0 col1" >0.998103</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col2" class="data row0 col2" >-0.605610</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col3" class="data row0 col3" >-0.130891</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col4" class="data row0 col4" >0.036182</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col5" class="data row0 col5" >0.550581</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow0_col6" class="data row0 col6" >-0.275456</td>
#             </tr>
#             <tr>
#                         <th id="T_99487d04_08b9_11ec_84a9_f80dac08874clevel0_row1" class="row_heading level0 row1" >Apparent Temperature (C)</th>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col0" class="data row1 col0" >0.998103</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col2" class="data row1 col2" >-0.594838</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col3" class="data row1 col3" >-0.169512</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col4" class="data row1 col4" >0.031809</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col5" class="data row1 col5" >0.534301</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow1_col6" class="data row1 col6" >-0.258583</td>
#             </tr>
#             <tr>
#                         <th id="T_99487d04_08b9_11ec_84a9_f80dac08874clevel0_row2" class="row_heading level0 row2" >Humidity</th>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col0" class="data row2 col0" >-0.605610</td>
#                         <td id="T_99487d04_08b9_11ec_84a9_f80dac08874crow2_col1" class="data row2 col1" >-0.594838</td>

# %% [markdown]
# * Resample Daily Humidity to Weekly Humidity
# * Plot Weekly Humidity

# %%
weather_weekly = weather_daily.resample('W').aggregate('mean')
fig, ax = plt.subplots(figsize=(10,10))

ax.scatter(weather_weekly.index.values,
          weather_weekly['Humidity'], color='green')
ax.set(xlabel='Date',ylabel='Humidity',title='Weekly Humidity')
plt.show()

# %%
weather_weekly_1 = weather_weekly.drop(labels='Loud Cover',axis=1)
weather_weekly_1.corr().style.background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col0,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col1,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col0,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col1,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow2_col2,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow3_col3,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow4_col4,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow5_col5,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow6_col6{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col2{
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col3{
#             background-color:  #b10b26;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col4{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col5{
#             background-color:  #51b35e;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col6{
#             background-color:  #e0422f;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col2{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col3,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow2_col0,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow2_col1,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow2_col4,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow2_col5,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow3_col6,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow5_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col4{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col5,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow5_col0{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col6{
#             background-color:  #e24731;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow2_col3{
#             background-color:  #f88950;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow2_col6{
#             background-color:  #dc3b2c;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow3_col0{
#             background-color:  #f7814c;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow3_col1{
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow3_col2{
#             background-color:  #feea9b;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow3_col4{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow3_col5{
#             background-color:  #fdfebc;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow4_col0{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow4_col1{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow4_col2,#T_9973e018_08b9_11ec_b9d9_f80dac08874crow5_col3{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow4_col3{
#             background-color:  #fede89;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow4_col5{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow4_col6{
#             background-color:  #c82227;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow5_col1{
#             background-color:  #5db961;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow5_col4{
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow5_col6{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow6_col0{
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow6_col1{
#             background-color:  #fee491;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow6_col2{
#             background-color:  #fee797;
#             color:  #000000;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow6_col3{
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow6_col4{
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }#T_9973e018_08b9_11ec_b9d9_f80dac08874crow6_col5{
#             background-color:  #fff2aa;
#             color:  #000000;
#         }</style><table id="T_9973e018_08b9_11ec_b9d9_f80dac08874c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperature (C)</th>        <th class="col_heading level0 col1" >Apparent Temperature (C)</th>        <th class="col_heading level0 col2" >Humidity</th>        <th class="col_heading level0 col3" >Wind Speed (km/h)</th>        <th class="col_heading level0 col4" >Wind Bearing (degrees)</th>        <th class="col_heading level0 col5" >Visibility (km)</th>        <th class="col_heading level0 col6" >Pressure (millibars)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9973e018_08b9_11ec_b9d9_f80dac08874clevel0_row0" class="row_heading level0 row0" >Temperature (C)</th>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col1" class="data row0 col1" >0.997925</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col2" class="data row0 col2" >-0.672089</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col3" class="data row0 col3" >-0.281170</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col4" class="data row0 col4" >0.146814</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col5" class="data row0 col5" >0.695543</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow0_col6" class="data row0 col6" >0.012994</td>
#             </tr>
#             <tr>
#                         <th id="T_9973e018_08b9_11ec_b9d9_f80dac08874clevel0_row1" class="row_heading level0 row1" >Apparent Temperature (C)</th>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col0" class="data row1 col0" >0.997925</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col2" class="data row1 col2" >-0.662691</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col3" class="data row1 col3" >-0.312781</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col4" class="data row1 col4" >0.140636</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col5" class="data row1 col5" >0.683497</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow1_col6" class="data row1 col6" >0.022341</td>
#             </tr>
#             <tr>
#                         <th id="T_9973e018_08b9_11ec_b9d9_f80dac08874clevel0_row2" class="row_heading level0 row2" >Humidity</th>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80dac08874crow2_col0" class="data row2 col0" >-0.672089</td>
#                         <td id="T_9973e018_08b9_11ec_b9d9_f80d

# %% [markdown]
# * Resampe Weekly Humidity to Monthly Humidity
# * Plot Monthly Humidity

# %%
weather_monthly = weather_weekly.resample('M').aggregate('mean')
fig, ax = plt.subplots(figsize=(10,10))

ax.scatter(weather_monthly.index.values,
          weather_monthly['Humidity'], color='green')
ax.set(xlabel='Date',ylabel='Humidity',title='Monthly Humidity')
plt.show()

# %% [markdown]
# #### Correlation Analysis

# %%
weather_monthly.corr().style.background_gradient(cmap="RdYlGn")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1126: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1127: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_999b2527_08b9_11ec_8461_f80dac08874crow0_col0,#T_999b2527_08b9_11ec_8461_f80dac08874crow0_col1,#T_999b2527_08b9_11ec_8461_f80dac08874crow1_col0,#T_999b2527_08b9_11ec_8461_f80dac08874crow1_col1,#T_999b2527_08b9_11ec_8461_f80dac08874crow2_col2,#T_999b2527_08b9_11ec_8461_f80dac08874crow3_col3,#T_999b2527_08b9_11ec_8461_f80dac08874crow4_col4,#T_999b2527_08b9_11ec_8461_f80dac08874crow5_col5,#T_999b2527_08b9_11ec_8461_f80dac08874crow7_col7{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow0_col2,#T_999b2527_08b9_11ec_8461_f80dac08874crow1_col2{
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow0_col3{
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow0_col4{
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow0_col5{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow0_col6,#T_999b2527_08b9_11ec_8461_f80dac08874crow1_col6,#T_999b2527_08b9_11ec_8461_f80dac08874crow2_col6,#T_999b2527_08b9_11ec_8461_f80dac08874crow3_col6,#T_999b2527_08b9_11ec_8461_f80dac08874crow4_col6,#T_999b2527_08b9_11ec_8461_f80dac08874crow5_col6,#T_999b2527_08b9_11ec_8461_f80dac08874crow6_col0,#T_999b2527_08b9_11ec_8461_f80dac08874crow6_col1,#T_999b2527_08b9_11ec_8461_f80dac08874crow6_col2,#T_999b2527_08b9_11ec_8461_f80dac08874crow6_col3,#T_999b2527_08b9_11ec_8461_f80dac08874crow6_col4,#T_999b2527_08b9_11ec_8461_f80dac08874crow6_col5,#T_999b2527_08b9_11ec_8461_f80dac08874crow6_col6,#T_999b2527_08b9_11ec_8461_f80dac08874crow6_col7,#T_999b2527_08b9_11ec_8461_f80dac08874crow7_col6{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow0_col7{
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow1_col3,#T_999b2527_08b9_11ec_8461_f80dac08874crow2_col0,#T_999b2527_08b9_11ec_8461_f80dac08874crow2_col1,#T_999b2527_08b9_11ec_8461_f80dac08874crow2_col4,#T_999b2527_08b9_11ec_8461_f80dac08874crow2_col5,#T_999b2527_08b9_11ec_8461_f80dac08874crow3_col7,#T_999b2527_08b9_11ec_8461_f80dac08874crow5_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow1_col4{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow1_col5,#T_999b2527_08b9_11ec_8461_f80dac08874crow5_col0{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow1_col7{
#             background-color:  #ee613e;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow2_col3{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow2_col7{
#             background-color:  #d93429;
#             color:  #f1f1f1;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow3_col0{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow3_col1{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow3_col2{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow3_col4{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow3_col5{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow4_col0{
#             background-color:  #d3ec87;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow4_col1{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow4_col2{
#             background-color:  #fb9d59;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow4_col3,#T_999b2527_08b9_11ec_8461_f80dac08874crow7_col2{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow4_col5{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow4_col7{
#             background-color:  #db382b;
#             color:  #f1f1f1;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow5_col1{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow5_col3{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow5_col4{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow5_col7{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow7_col0{
#             background-color:  #feeda1;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow7_col1{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow7_col3,#T_999b2527_08b9_11ec_8461_f80dac08874crow7_col4{
#             background-color:  #f46d43;
#             color:  #000000;
#         }#T_999b2527_08b9_11ec_8461_f80dac08874crow7_col5{
#             background-color:  #fffcba;
#             color:  #000000;
#         }</style><table id="T_999b2527_08b9_11ec_8461_f80dac08874c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperature (C)</th>        <th class="col_heading level0 col1" >Apparent Temperature (C)</th>        <th class="col_heading level0 col2" >Humidity</th>        <th class="col_heading level0 col3" >Wind Speed (km/h)</th>        <th class="col_heading level0 col4" >Wind Bearing (degrees)</th>        <th class="col_heading level0 col5" >Visibility (km)</th>        <th class="col_heading level0 col6" >Loud Cover</th>        <th class="col_heading level0 col7" >Pressure (millibars)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_999b2527_08b9_11ec_8461_f80dac08874clevel0_row0" class="row_heading level0 row0" >Temperature (C)</th>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow0_col1" class="data row0 col1" >0.998835</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow0_col2" class="data row0 col2" >-0.747787</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow0_col3" class="data row0 col3" >-0.452034</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow0_col4" class="data row0 col4" >0.318978</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow0_col5" class="data row0 col5" >0.799300</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow0_col7" class="data row0 col7" >0.027001</td>
#             </tr>
#             <tr>
#                         <th id="T_999b2527_08b9_11ec_8461_f80dac08874clevel0_row1" class="row_heading level0 row1" >Apparent Temperature (C)</th>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow1_col0" class="data row1 col0" >0.998835</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_999b2527_08b9_11ec_8461_f80dac08874crow1_col2" class="data row1 col2" >-0.743199

# %% [markdown]
# ##### As we can see the column `Loud Cover` has all zeros , lets drop the columan and then visualize the correlation matrix

# %%
weather_monthly_1 = weather_monthly.drop(labels='Loud Cover',axis=1)
weather_monthly_1.corr().style.background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col0,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col1,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col0,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col1,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col2,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow3_col3,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow4_col4,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow5_col5,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow6_col6{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col2,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col2{
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col3{
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col4{
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col5{
#             background-color:  #219c52;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col6{
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col3,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col0,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col1,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col4,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col5,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow3_col6,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow5_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col4{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col5,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow5_col0{
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col6{
#             background-color:  #ee613e;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col3{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col6{
#             background-color:  #d93429;
#             color:  #f1f1f1;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow3_col0{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow3_col1{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow3_col2{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow3_col4{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow3_col5{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow4_col0{
#             background-color:  #d3ec87;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow4_col1{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow4_col2{
#             background-color:  #fb9d59;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow4_col3,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow6_col2{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow4_col5{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow4_col6{
#             background-color:  #db382b;
#             color:  #f1f1f1;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow5_col1{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow5_col3{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow5_col4{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow5_col6{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow6_col0{
#             background-color:  #feeda1;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow6_col1{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow6_col3,#T_99b15c02_08b9_11ec_85f8_f80dac08874crow6_col4{
#             background-color:  #f46d43;
#             color:  #000000;
#         }#T_99b15c02_08b9_11ec_85f8_f80dac08874crow6_col5{
#             background-color:  #fffcba;
#             color:  #000000;
#         }</style><table id="T_99b15c02_08b9_11ec_85f8_f80dac08874c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperature (C)</th>        <th class="col_heading level0 col1" >Apparent Temperature (C)</th>        <th class="col_heading level0 col2" >Humidity</th>        <th class="col_heading level0 col3" >Wind Speed (km/h)</th>        <th class="col_heading level0 col4" >Wind Bearing (degrees)</th>        <th class="col_heading level0 col5" >Visibility (km)</th>        <th class="col_heading level0 col6" >Pressure (millibars)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_99b15c02_08b9_11ec_85f8_f80dac08874clevel0_row0" class="row_heading level0 row0" >Temperature (C)</th>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col1" class="data row0 col1" >0.998835</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col2" class="data row0 col2" >-0.747787</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col3" class="data row0 col3" >-0.452034</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col4" class="data row0 col4" >0.318978</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col5" class="data row0 col5" >0.799300</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow0_col6" class="data row0 col6" >0.027001</td>
#             </tr>
#             <tr>
#                         <th id="T_99b15c02_08b9_11ec_85f8_f80dac08874clevel0_row1" class="row_heading level0 row1" >Apparent Temperature (C)</th>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col0" class="data row1 col0" >0.998835</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col2" class="data row1 col2" >-0.743199</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col3" class="data row1 col3" >-0.469835</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col4" class="data row1 col4" >0.306240</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col5" class="data row1 col5" >0.794878</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow1_col6" class="data row1 col6" >0.036615</td>
#             </tr>
#             <tr>
#                         <th id="T_99b15c02_08b9_11ec_85f8_f80dac08874clevel0_row2" class="row_heading level0 row2" >Humidity</th>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col0" class="data row2 col0" >-0.747787</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col1" class="data row2 col1" >-0.743199</td>
#                         <td id="T_99b15c02_08b9_11ec_85f8_f80dac08874crow2_col2" class="data row2 co

# %% [markdown]
# # Data PreProcessing & Cleanup

# %% [markdown]
# ### Hourly Dataset

# %% [markdown]
# #### Check data quality

# %%
weather_hourly.isnull().sum()
# Out:
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %% [markdown]
# > Dataset is pretty clean with only 1 column 'Precip Type' having null values.
# > As part of the 1st iteration, lets drop this feature and proceed. In the later part we will include this feature and check if it helps in giving a better prediction of Humidity

# %%
def min_max(input_df):
    max_series = input_df.max(numeric_only=True)
    min_series = input_df.min(numeric_only=True)
    min_max = pd.DataFrame(max_series).transpose().append(pd.DataFrame(min_series).transpose())
    return min_max

min_max(weather_hourly)
# Out:
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0        39.905556                 39.344444       1.0            63.8526
# 0       -21.822222                -27.716667       0.0             0.0000
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)
# 0                   359.0             16.1         0.0               1046.38
# 0                     0.0              0.0         0.0                  0.00

# %% [markdown]
# _Steps Performed_
# * Drop the Precipe Type column
# * Drop the target column __Humidity__
# * The numerical ( continous ) features have values in different scale. e.g __Apparent Temperature__ values ranges between *39.34444*  and *-27.7166* while __Wind Speed__ values ranges between *359* and *0*. We use `StandardScalar` to perform normalization
# * The categorical columns are label encoded using `LabelEncoder`

# %%
class DataWrangler_Approach_A():
    def __init__(self,df):
        self.df = df
        
    def _get_numerical_columns(self):
        return self.df.select_dtypes(include=['float64','int64']).columns
        
    def _get_categorical_columns(self):
        return self.df.select_dtypes(include=['object']).columns
    
    def _remove_columns(self,labels):
        self.df.drop(labels=labels,axis=1,inplace=True)

    
    def _drop_rows_with_null(self):
        self.df.dropna(inplace=True,axis=1)
    
    def _scale_numerical_features(self):
        scaler = preprocessing.StandardScaler()
        numerical_cols = self._get_numerical_columns()
        numerical_df = self.df.loc[:,numerical_cols]
        self.df.drop(labels=numerical_cols, axis=1, inplace=True)
        scaler.fit(numerical_df)
        scaled_cols = scaler.transform(numerical_df)
        self.df[numerical_cols] = scaled_cols
    
    def _label_encode_categories(self):
        le = preprocessing.LabelEncoder()
        categorical_cols = self._get_categorical_columns()
        categorical_df = self.df.loc[:,categorical_cols]
        categorical_df = categorical_df.apply(le.fit_transform)
        self.df[categorical_cols] = categorical_df
        
    
    def perform_wrangling(self):
        #self._remove_columns(['Humidity'])
        self._drop_rows_with_null()
        self._scale_numerical_features()
        self._label_encode_categories()
        dropna=True
        return (self.df,dropna)

# %%
raw_df = pd.read_csv('weatherHistory.csv',
                             index_col=['Formatted Date'],
                             na_values=['9999.99'])
raw_df.index = raw_df.index.str.replace('\+0200','')
raw_df.index=pd.to_datetime(raw_df.index,format="%Y-%m-%d %H:%M:%S", utc= True)
raw_df.head(5)
y = raw_df['Humidity']
raw_df.drop(labels=['Loud Cover'],axis=1,inplace=True)
(pre_processed_df, dropna) = DataWrangler_Approach_A(raw_df).perform_wrangling()
pre_processed_df.head()
# Out:
#                            Summary  Daily Summary  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00+00:00       19            197        -0.257599
# 2006-04-01 01:00:00+00:00       19            197        -0.269814
# 2006-04-01 02:00:00+00:00       17            197        -0.267487
# 2006-04-01 03:00:00+00:00       19            197        -0.381489
# 2006-04-01 04:00:00+00:00       17            197        -0.332631
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-04-01 00:00:00+00:00                 -0.324035  0.793470
# 2006-04-01 01:00:00+00:00                 -0.339097  0.639996
# 2006-04-01 02:00:00+00:00                 -0.138102  0.793470
# 2006-04-01 03:00:00+00:00                 -0.459071  0.486521
# 2006-04-01 04:00:00+00:00                 -0.362469  0.486521
#
#                            Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# 2006-04-01 00:00:00+00:00           0.478635                0.591256
# 2006-04-01 01:00:00+00:00           0.499594                0.665756
# 2006-04-01 02:00:00+00:00          -0.995473                0.153570
# 2006-04-01 03:00:00+00:00           0.476306                0.758881
# 2006-04-01 04:00:00+00:00           0.033841                0.665756
#
#                            Visibility (km)  Pressure (millibars)
# Formatted Date
# 2006-04-01 00:00:00+00:00         1.306976              0.101685
# 2006-04-01 01:00:00+00:00         1.306976              0.105960
# 2006-04-01 02:00:00+00:00         1.099586              0.108610
# 2006-04-01 03:00:00+00:00         1.306976              0.112628
# 2006-04-01 04:00:00+00:00         1.306976              0.113483

# %%
pre_processed_df.corr().style.background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col0,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col1,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col2,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col3,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col4,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col5,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col6,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col7,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col8{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col1,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col2{
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col2{
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col3{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col4{
#             background-color:  #fdb768;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col5,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col8{
#             background-color:  #ef633f;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col6{
#             background-color:  #b50f26;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow0_col7{
#             background-color:  #fed27f;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col0{
#             background-color:  #f88950;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col2{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col3{
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col4,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col4{
#             background-color:  #e95538;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col5{
#             background-color:  #ee613e;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col6{
#             background-color:  #c41e27;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col7,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col1{
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow1_col8{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col0{
#             background-color:  #f7814c;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col1{
#             background-color:  #dcf08f;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col3,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col2{
#             background-color:  #016a38;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col4,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col0,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col1,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col2,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col3,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col5,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col7,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col8,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col6{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col5{
#             background-color:  #f16640;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col6,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col8,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col6{
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow2_col7{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col0,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col0,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col0{
#             background-color:  #f67f4b;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col1{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col4{
#             background-color:  #ad0826;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col5{
#             background-color:  #e24731;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col7{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow3_col8{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col6{
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow4_col8{
#             background-color:  #be1827;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col0,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col8{
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col1,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col5,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col5{
#             background-color:  #fa9857;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col2,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col3,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col4{
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col3,#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col7{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col4{
#             background-color:  #f88c51;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow5_col6{
#             background-color:  #db382b;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col0{
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col1{
#             background-color:  #fdb163;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col2{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col4{
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col7{
#             background-color:  #fdaf62;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow6_col8{
#             background-color:  #b71126;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col2{
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col3{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow7_col6{
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col1{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col3{
#             background-color:  #fed481;
#             color:  #000000;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col5{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }#T_9a71ede1_08b9_11ec_8774_f80dac08874crow8_col7{
#             background-color:  #fdb567;
#             color:  #000000;
#         }</style><table id="T_9a71ede1_08b9_11ec_8774_f80dac0887

# %%
# Drop the target column
pre_processed_df.drop(labels=['Humidity'],axis=1,inplace=True)

# %%
def select_feature(feat_sel_func,k,**kwargs):
    fs = SelectKBest(score_func=feat_sel_func,k=k)
    fs.fit(X_train,y_train)
    X_train_fs = fs.transform(X_train)
    X_test_fs = fs.transform(X_test)
    return X_train_fs,X_test_fs,fs

# %%
def select_feature_freg(**kwargs):
    feat_count = kwargs['feature_count']
    X_train_fs, X_test_fs, fs = select_feature(f_regression,feat_count,
                                               X_test=X_test,
                                               X_train=X_train,y_train=y_train)
    mask = fs.get_support(indices=True)
    features = [pre_processed_df.columns[index] for index in mask]
    scores = [fs.scores_[index] for index in mask]
    selected_feature_df = pd.DataFrame(X_train,columns=features)
    if print_score:
        for i in range(len(scores)):
            print(f'Feature {selected_feature_df.columns[i]} score : {fs.scores_[i]}')

    plt.barh([selected_feature_df.columns[i] for i in range(len(features))], scores)
    plt.tight_layout()
    plt.show()
    return X_train_fs, X_test_fs

# %%
def select_feature_mutualinfo(**kwargs):
    feat_count=kwargs['feature_count']
    X_train_fs, X_test_fs, fs = select_feature(mutual_info_regression,feat_count,
                                               X_test=X_test,
                                               X_train=X_train,y_train=y_train)
    mask = fs.get_support(indices=True)
    features = [pre_processed_df.columns[index] for index in mask]
    scores = [fs.scores_[index] for index in mask]
    selected_feature_df = pd.DataFrame(X_train,columns=features)
    if print_score:
        for i in range(len(scores)):
            print(f'Feature {selected_feature_df.columns[i]} score : {fs.scores_[i]}')

    plt.barh([selected_feature_df.columns[i] for i in range(len(features))], scores)
    plt.tight_layout()
    plt.show()
    return X_train_fs,X_test_fs

# %%
def perform_linearreg(**kwargs):
    X_train = kwargs['X_train']
    y_train = kwargs['y_train']
    X_test = kwargs['X_test']
    y_test = kwargs['y_test']
    reg = LinearRegression().fit(X_train, y_train)
    score = reg.score(X_test, y_test)
    y_pred = reg.predict(X_test)
    print(f'Training dataset shape: {X_train.shape}')
    print(f'Test dataset shape: {X_test.shape}')
    print(f'{color.BOLD}Accuracy Score {color.END} {score:.4f}')
    print(f'{color.BOLD}Mean squared error:{color.END} {mean_squared_error(y_test, y_pred):.4f}')
    print(f'{color.BOLD}Root Mean squared error:{color.END} {mean_squared_error(y_test, y_pred,squared=False):.4f}')
    
    fig, ax = plt.subplots(figsize=(10,10))
    ax.scatter(y_test, y_pred, edgecolors=(0, 0, 0))
    ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
    ax.set_xlabel('Measured')
    ax.set_ylabel('Predicted')
    plt.show()

# %%
def perform_ridgereg(**kwargs):
    X_train = kwargs['X_train']
    y_train = kwargs['y_train']
    X_test = kwargs['X_test']
    y_test = kwargs['y_test']
    r_reg = Ridge(alpha=1.0,solver='svd').fit(X_train, y_train)
    score = r_reg.score(X_test, y_test)
    y_pred = r_reg.predict(X_test)
    print(f'Training dataset shape: {X_train.shape}')
    print(f'Test dataset shape: {X_test.shape}')
    print(f'{color.BOLD}Accuracy Score {color.END} {score:.4f}')
    print(f'{color.BOLD}Mean squared error:{color.END} {mean_squared_error(y_test, y_pred):.4f}')
    print(f'{color.BOLD}Root Mean squared error:{color.END} {mean_squared_error(y_test, y_pred,squared=False):.4f}')
    
    fig, ax = plt.subplots(figsize=(10,10))
    ax.scatter(y_test, y_pred, edgecolors=(0, 0, 0))
    ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
    ax.set_xlabel('Measured')
    ax.set_ylabel('Predicted')
    plt.show()

# %%
def perform_decisiontreereg(**kwargs):
    X_train = kwargs['X_train']
    y_train = kwargs['y_train']
    X_test = kwargs['X_test']
    y_test = kwargs['y_test']
    dtree_reg = DecisionTreeRegressor(random_state=0).fit(X_train, y_train)
    score = dtree_reg.score(X_test, y_test)
    y_pred = dtree_reg.predict(X_test)
    print(f'Training dataset shape: {X_train.shape}')
    print(f'Test dataset shape: {X_test.shape}')
    print(f'{color.BOLD}Accuracy Score {color.END} {score:.4f}')
    print(f'{color.BOLD}Mean squared error:{color.END} {mean_squared_error(y_test, y_pred):.4f}')
    print(f'{color.BOLD}Root Mean squared error:{color.END} {mean_squared_error(y_test, y_pred,squared=False):.4f}')
    
    fig, ax = plt.subplots(figsize=(10,10))
    ax.scatter(y_test, y_pred, edgecolors=(0, 0, 0))
    ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
    ax.set_xlabel('Measured')
    ax.set_ylabel('Predicted')
    plt.show()

# %%
def perform_randomforestreg(**kwargs):
    X_train = kwargs['X_train']
    y_train = kwargs['y_train']
    X_test = kwargs['X_test']
    y_test = kwargs['y_test']
    random_reg = RandomForestRegressor(n_estimators = 100, random_state=0).fit(X_train, y_train)
    score = random_reg.score(X_test, y_test)
    y_pred = random_reg.predict(X_test)
    print(f'Training dataset shape: {X_train.shape}')
    print(f'Test dataset shape: {X_test.shape}')
    print(f'{color.BOLD}Accuracy Score {color.END} {score:.4f}')
    print(f'{color.BOLD}Mean squared error:{color.END} {mean_squared_error(y_test, y_pred):.4f}')
    print(f'{color.BOLD}Root Mean squared error:{color.END} {mean_squared_error(y_test, y_pred,squared=False):.4f}')
    
    fig, ax = plt.subplots(figsize=(10,10))
    ax.scatter(y_test, y_pred, edgecolors=(0, 0, 0))
    ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
    ax.set_xlabel('Measured')
    ax.set_ylabel('Predicted')
    plt.show()

# %% [markdown]
# ### Feature Selection
# * Train Test Split
# * Linear Reg with all features
# * f_regression feature selection
# * Linear regression with K best features
# * mutual_info_regression feature selection

# %%
X_train, X_test, y_train, y_test = train_test_split(pre_processed_df,y,random_state=42)

freg_feature_count = 6
print_score = False
print(f'{color.BLUE}Select {freg_feature_count} Best features using f_regression{color.END}')
X_train_freg, X_test_freg = select_feature_freg(X_train=X_train,y_train=y_train,
                                            X_test=X_test,feature_count=freg_feature_count,
                                            print_score=print_score)
minfo_feature_count = 6
print_score = False
print(f'{color.BLUE}Select {minfo_feature_count} Best features using mutual_info_regression{color.END}')
X_train_mreg, X_test_mreg = select_feature_mutualinfo(X_train=X_train,
                                            X_test=X_test,feature_count=minfo_feature_count,
                                            print_score=print_score)
# Out:
# Select 6 Best features using f_regression
# Select 6 Best features using mutual_info_regression

# %% [markdown]
# ## Linear Regression

# %%
l_reg_allfeat = perform_linearreg(X_train=X_train,X_test=X_test,y_train=y_train,y_test=y_test)
l_reg_freg = perform_linearreg(X_train=X_train_freg,X_test=X_test_freg,y_train=y_train,y_test=y_test)
l_reg_minfo = perform_linearreg(X_train=X_train_mreg,X_test=X_test_mreg,y_train=y_train,y_test=y_test)
# Out:
# Training dataset shape: (72339, 8)
# Test dataset shape: (24114, 8)
# Accuracy Score  0.4741
# Mean squared error: 0.0201
# Root Mean squared error: 0.1417
# Training dataset shape: (72339, 6)
# Test dataset shape: (24114, 6)
# Accuracy Score  0.4727
# Mean squared error: 0.0201
# Root Mean squared error: 0.1419
# Training dataset shape: (72339, 6)
# Test dataset shape: (24114, 6)
# Accuracy Score  0.4727
# Mean squared error: 0.0201
# Root Mean squared error: 0.1419

# %% [markdown]
# ## Random Forest Regression

# %%
print(f'{color.BLUE} RandomForest Regression using all features {color.END}')
random_reg_allfeat = perform_randomforestreg(X_train=X_train,X_test=X_test,
                                             y_train=y_train,y_test=y_test)
print(f'{color.BLUE} RandomForest Regression using 6 top features selected using `f_regression` {color.END}')
random_reg_freg = perform_randomforestreg(X_train=X_train_freg,X_test=X_test_freg,
                              y_train=y_train,y_test=y_test)
print(f'{color.BLUE} RandomForest Regression using 6 top features selected using `mutual_info_regression` {color.END}')
random_reg_minfo = perform_randomforestreg(X_train=X_train_mreg,X_test=X_test_mreg,
                                y_train=y_train,y_test=y_test)
# Out:
#  RandomForest Regression using all features
# Training dataset shape: (72339, 8)
# Test dataset shape: (24114, 8)
# Accuracy Score  0.7653
# Mean squared error: 0.0090
# Root Mean squared error: 0.0947
#  RandomForest Regression using 6 top features selected using `f_regression`
# Training dataset shape: (72339, 6)
# Test dataset shape: (24114, 6)
# Accuracy Score  0.7183
# Mean squared error: 0.0108
# Root Mean squared error: 0.1037
#  RandomForest Regression using 6 top features selected using `mutual_info_regression`
# Training dataset shape: (72339, 6)
# Test dataset shape: (24114, 6)
# Accuracy Score  0.7183
# Mean squared error: 0.0108
# Root Mean squared error: 0.1037

# %% [markdown]
# ## DecisionTree Regression

# %%
print(f'{color.BLUE} DecisionTree Regression using all features {color.END}')
dtree_reg_allfeat = perform_decisiontreereg(X_train=X_train,X_test=X_test,
                                             y_train=y_train,y_test=y_test)
print(f'{color.BLUE} DecisionTree Regression using 6 top features selected using `f_regression` {color.END}')
dtree_reg_freg = perform_decisiontreereg(X_train=X_train_freg,X_test=X_test_freg,
                              y_train=y_train,y_test=y_test)
print(f'{color.BLUE} DecisionTree Regression using 6 top features selected using `mutual_info_regression` {color.END}')
dtree_reg_minfo = perform_decisiontreereg(X_train=X_train_mreg,X_test=X_test_mreg,
                                y_train=y_train,y_test=y_test)
# Out:
#  DecisionTree Regression using all features
# Training dataset shape: (72339, 8)
# Test dataset shape: (24114, 8)
# Accuracy Score  0.5287
# Mean squared error: 0.0180
# Root Mean squared error: 0.1341
#  DecisionTree Regression using 6 top features selected using `f_regression`
# Training dataset shape: (72339, 6)
# Test dataset shape: (24114, 6)
# Accuracy Score  0.4674
# Mean squared error: 0.0203
# Root Mean squared error: 0.1426
#  DecisionTree Regression using 6 top features selected using `mutual_info_regression`
# Training dataset shape: (72339, 6)
# Test dataset shape: (24114, 6)
# Accuracy Score  0.4674
# Mean squared error: 0.0203
# Root Mean squared error: 0.1426

# %% [markdown]
# # Since the target is not categorical in nature, Confusion mattrix can not be applied here.
